# %% [markdown]
# # 전처리 연습 (Tokenize, Cleansing & Normalization, Stemming & Lemmatization)
#
# 1. 데이터셋(corpus)을 찾는다. (만들어진 데이터셋, 크롤링, ...)
#     - **🐿️ 이어지는 실습에 쓸 수 있을 법한 데이터 찾기 Tip**
#     - 여러 문장으로 이루어진 데이터셋이라면 일단 good
#         - 리뷰 등 이어지지 않는 짧은 문장 여러 건 ok
#         - 소설 등 이어지는 긴 문장 여러 건 ok
#     - 대화형 데이터셋도 good
#         - QnA로 구성되어 있는 corpus도 좋고
#         - 일반적인 대화로 구성되어 있는 corpus도 좋아요~
#     - 특정 도메인에 대한 정보를 담고 있는 데이터셋도 good
# 2. 전처리를 해본다.
#     - 텍스트 자체를 깔끔하게 만드는 것까지만

# %%
import pandas as pd
import re
path= "./data/IT과학/practice_뉴스_IT과학.txt"
raw = open(path, encoding="utf-8").read()

docs = [d.strip() for d in re.split(r"\n\s*\n+", raw) if d.strip()]

# %%
import kss # 문장단위  , okt는 단어(형태소) 단위
from konlpy.tag import Okt

sample = docs[0]
sent = kss.split_sentences(sample)

# %%
okt = Okt()
tokens_morphs = okt.morphs(docs[0]) # morphs는 형태소 단위로 토큰화
texts = okt.morphs(raw)
texts
print(texts)
# Out:
# ['엔씨소프트', '(', '대표', '김택진', ')', '는', 'PC', 'MMORPG', '＇', '블레이드', '&', '소울', '＇', '에', '신규', '각성', '계열', '＇', '음양', '＇', '을', '추가', '했다', '.', '\n', '음양', '은', '＇', '기공사', '＇', '의', '각성', '계열', '로', '＇', '초열', '＇', '과', '＇', '혹', '한', '＇', '에', '이', '은', '세', '번째', '계열', '이다', '.', '\n', '한', '곳', '에', '집중', '되는', '음', '의', '기운', '과', '넓게', '퍼지는', '양', '의', '기운', '을', '바탕', '으로', '번개', '를', '사용', '하는', '것', '이', '특징', '이다', '.', '\n', '특히', '특수', '무공', '인', '＇', '뇌', '신화', '＇', '를', '사용', '하면', '부유', '상태', '가', '되며', '이를', '통해', '속', '도감', '있는', '전투', '를', '즐길', '수', '있다', '.', '\n', '엔씨소프트', '는', '＇', '일단', '받고', '시작', '!', '＇', '이벤트', '를', '4월', '1일', '까지', '진행', '한다', '.', '\n', '라이브', '월드', '의', '＇', '신', '석', '샵', '＇', '에서', '음양', '육성', '을', '지원', '하는', '아이템', '인', '＇', '고속', '성장', '이용권', '＇', ',', '＇', '음양', '전용', '의천', '신', '공', '패', '＇', ',', '＇', '음양', '전용', '두', '악', '비', '공', '패', '＇', ',', '＇', '음양', '전용', '천', '곤', '팔찌', '1', '단계', '＇', '등', '을', '0', '신', '석', '(', '무료', ')', '에', '획득', '할', '수', '있다', '.', '\n', '55', '레벨', '이상', '의', '이용자', '는', '＇', '대', '협의', '클라', '쓰', '＇', '이벤트', '에', '4월', '8일', '까지', '참여', '할', '수', '있다', '.', '\n', '이벤트', '기간', '동안', '서신', '을', '통해', '＇', '꺼지지', '않는', '불씨', '＇', '퀘스트', '를', '받은', '이후', '통합', '던전', '에서', '＇', '영', '겁', '의', '무덤', '＇', '및', '＇', '타오르는', '영', '겁', '의', '무덤', '＇', '에', '입장', '해', '각', '보스', '몬스터', '＇', '멸', '화', '대성', '＇', '과', '＇', '진', '멸', '화', '대성', '＇', '을', '공략', '할', '수', '있다', '.', '\n', '또', '보스', '몬스터', '를', '제압', '해', '일', '일', '퀘스트', '를', '완료', '하면', '보상', '으로', '100만', '경험치', ',', '＇', '대', '협의', '비늘', '상자', '＇', ',', '＇', '영', '겁', '주화', '＇', '를', '얻을', '수', '있으며', '이용자', '는', '획득', '한', '＇', '영', '겁', '주화', '＇', '를', '이용', '해', '게임', '내', '상점', '＇', '비룡', '공상', '＇', '에서', '＇', '바리스타', '의상', '세트', '상자', '＇', ',', '＇', '칠흑', '의', '불멸', '날개', '＇', ',', '＇', '이글거리는', '광석', '상자', '＇', '등', '으로', '교환', '할', '수', '있다', '.', '\n', '이외', '에도', '＇', '타오르는', '영', '겁', '의', '무덤', '신속', '처치', '＇', '업적', '을', '달성', '하고', '칭호', '＇', '불멸', '＇', '을', '획득', '할', '수도', '있다', '.', '\n', '이벤트', '페이지', '내', '＇', '명예', '의', '전당', '＇', '에', '캐릭터', '명도', '등록', '되며', '신규', '날개', '＇', '영', '겁', '의', '불멸', '날개', '＇', ',', '신규', '환영', '무기', '＇', '백화', '난만', '환영', '무기', '상자', '＇', '를', '추가', '로', '받을', '수', '있다', '.', '\n\n', 'LG', '디스플레이', '가', '오는', '11월', '미국', '새너제이', '에서', '`', '오픈', '이노베이션', '포럼', '(', 'Open', 'Innovation', 'Forum', '·', 'OIF', ')', '2022', '`', '의', '일환', '으로', '`', '챌', '린지', '프로그램', '`', '을', '연', '다', '.', '\n', '한국', '·', '미국', '스타트업', '과', '함께', '디스플레이', '의', '새로운', '가치', '를', '발굴', '하고', '공동', '사업', '을', '추진', '하기', '위', '한', '포석', '이다', '.', '\n', '그동안', 'LG', '디스플레이', '는', '투명', '유기발광다이오드', '(', 'OLED', ')', '등', '에', '새로운', '가치', '를', '부여', '하고자', '이', '달', '미국', '라스베이거스', '에서', 'OIF', '를', '열었다', '.', '\n', '이후', '스타트업', '과', 'OLED', '생태계', '확대', '를', '위해', '과제', '제안', '서', '접수', '→', '1', '차', '심사', '→', '사업', '화', '검증', '(', 'PoC', ')', '→', '미국', '새너제이', '에서', '데모', '데이', '→', '투자', '검토', '를', '순차', '적', '으로', '진행', '할', '방침', '이다', '.', '\n', 'OIF', '는', '스타트업', '을', '포함', '한', '산업', '파트너', '와', '함께', '투명', 'OLED', '솔루션', '등', '에', '대한', '새로운', '비전을', '제시', '하기', '위해', '추진', '되고', '있다', '.', '\n', 'LG', '디스플레이', '는', '`', '다양한', '투명', 'OLED', '솔루션', '을', '통해', '디스플레이', '를', '혁신', '하겠다', '`', '면서', '`', '이를', '통해', '디스플레이', '에', '새로운', '가치', '를', '부여', '하고', '시장', '주도', '권', '을', '유지', '하겠다', '`', '고', '설명', '했다', '.', '\n', '이', '달', '라스베이거스', '에서', '열린', 'OIF', '2022', '에선', '수많은', '투명', 'OLED', '솔루션', '들', '을', '선보였다', '.', '\n', '세계', '적', '인', '건축', '설계', '업체', '겐슬러', '와', '손잡고', '선보인', '`', '사', '무용', '투명', 'OLED', '파티션', '`', '이', '대표', '적', '이다', '.', '\n', '그동안', '파티션', '은', '공간', '분리', '기능', '만', '있었지만', ',', '파티션', '을', '투명', 'OLED', '로', '구성', '해', '별도', '모니터', '·', 'TV', '가', '없어도', '즉석', '에서', '영상', '회의', '와', '프레', '젠', '테이', '션', '등', '을', '진행', '할', '수', '있도록', '구성', '했다', '.', '\n', '파티션', '이', '곧', '모니터', '가', '될', ' ...

# %%
ko_stopwords = set("아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼	어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다	하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영".split())

# clean_tokens = [token for token in tokens if token not in ko_stopwords]
preprocessed_tokens = []

for text in texts:
    tokens = okt.morphs(text, stem=True) # 형태소 분석과 동시에 어간 추출(stemming) 적용
    tokens = [t for t in tokens if t not in ko_stopwords]
    tokens = [re.sub(r"[^가-힣A-Za-z0-9]+", "", t) for t in tokens]
    tokens = [t for t in tokens if t]  # 빈 문자열 제거
    tokens = [t for t in tokens if len(t) > 1]  # 길이 1 이하 토큰 제거 (선택)

    if tokens:  # 빈 리스트 제외
        preprocessed_tokens.append(tokens)

# %%
preprocessed_tokens
# Out:
# [['엔씨소프트'],
#  ['대표'],
#  ['김택진'],
#  ['늘다'],
#  ['PC'],
#  ['MMORPG'],
#  ['블레이드'],
#  ['소울'],
#  ['신규'],
#  ['각성'],
#  ['계열'],
#  ['음양'],
#  ['추가'],
#  ['음양'],
#  ['기공사'],
#  ['각성'],
#  ['계열'],
#  ['초열'],
#  ['번째'],
#  ['계열'],
#  ['이다'],
#  ['집중'],
#  ['기운'],
#  ['넓다'],
#  ['퍼지다'],
#  ['기운'],
#  ['바탕'],
#  ['번개'],
#  ['사용'],
#  ['특징'],
#  ['이다'],
#  ['특히'],
#  ['특수'],
#  ['무공'],
#  ['신화'],
#  ['사용'],
#  ['부유'],
#  ['상태'],
#  ['가다'],
#  ['통해'],
#  ['도감'],
#  ['전투'],
#  ['즐기다'],
#  ['엔씨소프트'],
#  ['늘다'],
#  ['받다'],
#  ['시작'],
#  ['이벤트'],
#  ['4월'],
#  ['1일'],
#  ['진행'],
#  ['라이브'],
#  ['월드'],
#  ['음양'],
#  ['육성'],
#  ['지원'],
#  ['아이템'],
#  ['고속'],
#  ['성장'],
#  ['이용권'],
#  ['음양'],
#  ['전용'],
#  ['의천'],
#  ['음양'],
#  ['전용'],
#  ['음양'],
#  ['전용'],
#  ['팔찌'],
#  ['단계'],
#  ['무료'],
#  ['획득'],
#  ['55'],
#  ['레벨'],
#  ['이용자'],
#  ['늘다'],
#  ['대다'],
#  ['협의'],
#  ['크다'],
#  ['쓰다'],
#  ['이벤트'],
#  ['4월'],
#  ['8일'],
#  ['참여'],
#  ['이벤트'],
#  ['기간'],
#  ['서신'],
#  ['통해'],
#  ['꺼지다'],
#  ['불씨'],
#  ['퀘스트'],
#  ['받다'],
#  ['이후'],
#  ['통합'],
#  ['던전'],
#  ['무덤'],
#  ['타오르다'],
#  ['무덤'],
#  ['입장'],
#  ['보스'],
#  ['몬스터'],
#  ['대성'],
#  ['대성'],
#  ['공략'],
#  ['보스'],
#  ['몬스터'],
#  ['제압'],
#  ['퀘스트'],
#  ['완료'],
#  ['보상'],
#  ['100만'],
#  ['경험치'],
#  ['대다'],
#  ['협의'],
#  ['비늘'],
#  ['상자'],
#  ['주화'],
#  ['얻다'],
#  ['이용자'],
#  ['늘다'],
#  ['획득'],
#  ['주화'],
#  ['이용'],
#  ['게임'],
#  ['상점'],
#  ['비룡'],
#  ['공상'],
#  ['바리스타'],
#  ['의상'],
#  ['세트'],
#  ['상자'],
#  ['칠흑'],
#  ['불멸'],
#  ['날개'],
#  ['이글거리다'],
#  ['광석'],
#  ['상자'],
#  ['교환'],
#  ['이외'],
#  ['에도'],
#  ['타오르다'],
#  ['무덤'],
#  ['신속'],
#  ['처치'],
#  ['업적'],
#  ['달성'],
#  ['칭호'],
#  ['불멸'],
#  ['획득'],
#  ['수도'],
#  ['이벤트'],
#  ['페이지'],
#  ['명예'],
#  ['전당'],
#  ['캐릭터'],
#  ['명도'],
#  ['등록'],
#  ['신규'],
#  ['날개'],
#  ['불멸'],
#  ['날개'],
#  ['신규'],
#  ['환영'],
#  ['무기'],
#  ['백화'],
#  ['난만'],
#  ['환영'],
#  ['무기'],
#  ['상자'],
#  ['추가'],
#  ['받다'],
#  ['LG'],
#  ['디스플레이'],
#  ['가다'],
#  ['오다'],
#  ['11월'],
#  ['미국'],
#  ['새너제이'],
#  ['오픈'],
#  ['이노베이션'],
#  ['포럼'],
#  ['Open'],
#  ['Innovation'],
#  ['Forum'],
#  ['OIF'],
#  ['2022'],
#  ['일환'],
#  ['채다'],
#  ['린지'],
#  ['프로그램'],
#  ['한국'],
#  ['미국'],
#  ['스타트업'],
#  ['디스플레이'],
#  ['새롭다'],
#  ['가치'],
#  ['발굴'],
#  ['공동'],
#  ['사업'],
#  ['추진'],
#  ['포석'],
#  ['이다'],
#  ['그동안'],
#  ['LG'],
#  ['디스플레이'],
#  ['늘다'],
#  ['투명'],
#  ['유기발광다이오드'],
#  ['OLED'],
#  ['새롭다'],
#  ['가치'],
#  ['부여'],
#  ['미국'],
#  ['라스베이거스'],
#  ['OIF'],
#  ['열다'],
#  ['이후'],
#  ['스타트업'],
#  ['OLED'],
#  ['생태계'],
#  ['확대'],
#  ['위해'],
#  ['과제'],
#  ['제안'],
#  ['서다'],
#  ['접수'],
#  ['심사'],
#  ['사업'],
#  ['검증'],
#  ['PoC'],
#  ['미국'],
#  ['새너제이'],
#  ['데모'],
#  ['데이'],
#  ['투자'],
#  ['검토'],
#  ['순차'],
#  ['진행'],
#  ['방침'],
#  ['이다'],
#  ['OIF'],
#  ['늘다'],
#  ['스타트업'],
#  ['포함'],
#  ['산업'],
#  ['파트너'],
#  ['오다'],
#  ['투명'],
#  ['OLED'],
#  ['솔루션'],
#  ['대한'],
#  ['새롭다'],
#  ['비다'],
#  ['제시'],
#  ['위해'],
#  ['추진'],
#  ['LG'],
#  ['디스플레이'],
#  ['늘다'],
#  ['다양하다'],
#  ['투명'],
#  ['OLED'],
#  ['솔루션'],
#  ['통해'],
#  ['디스플레이'],
#  ['혁신'],
#  ['면서'],
#  ['통해'],
#  ['디스플레이'],
#  ['새롭다'],
#  ['가치'],
#  ['부여'],
#  ['시장'],
#  ['주도'],
#  ['유지'],
#  ['설명'],
#  ['라스베이거스'],
#  ['열리다'],
#  ['OIF'],
#  ['2022'],
#  ['에선'],
#  ['수많다'],
#  ['투명'],
#  ['OLED'],
#  ['솔루션'],
#  ['들다'],
#  ['선보이다'],
#  ['세계'],
#  ['건축'],
#  ['설계'],
#  ['업체'],
#  ['겐슬러'],
#  ['오다'],
#  ['손잡다'],
#  ['선보이다'],
#  ['무용'],
#  ['투명'],
#  ['OLED'],
#  ['파티션'],
#  ['대표'],
#  ['이다'],
#  ['그동안'],
#  ['파티션'],
#  ['공간'],
#  ['분리'],
#  ['기능'],
#  ['파티션'],
#  ['투명'],
#  ['OLED'],
#  ['구성'],
#  ['별도'],
#  ['모니터'],
#  ['TV'],
#  ['가다'],
#  ['즉석'],
#  ['영상'],
#  ['회의'],
#  ['오다'],
#  ['프레'],
#  ['테이'],
#  ['진행'],
#  ['구성'],
#  ['파티션'],
#  ['모니터'],
#  ['가다'],
#  ['이다'],
#  ['한국'],
#  ['인테리어'],
#  ['기업인'],
#  ['엑사'],
#  ['엔씨'],
#  ['오다'],
#  ['협업'],
#  ['회의실'],
#  ['투명'],
#  ['OLED'],
#  ['솔루션'],
#  ['선보이다'],
#  ['회의실'],
#  ['크다'],
#  ['유리'],
#  ['벽면'],
#  ['투명'],
#  ['OLED'],
#  ['구성'],
#  ['벽면'],
#  ['전체'],
#  ['디스플레이'],
#  ['활용'],
#  ['특징'],
#  ['이다'],
#  ['스타트업'],
#  ['이다'],
#  ['벽면'],
#  ['투명'],
#  ['OLED'],
#  ['덧붙이다'],
#  ['사무실'],
#  ['호텔'],
#  ['병원'],
#  ['다양하다'],
#  ['용도'],
#  ['사용'],
#  ['디스플레이'],
#  ['내놓다'],
#  ['LG'],
#  ['디스플레이'],
#  ['늘다'],
#  ['터치'],
#  ['기능'],
#  ['도입'],
#  ['패드'],
#  ['미디어'],
#  ['갤러리'],
#  ['사용'],
#  ['가능하다'],
#  ['투명'],
#  ['갤러리'],
#  ['이다'],
#  ['미디어'],
#  ['와의'],
#  ['협업'],
#  ['투명'],
#  ['OLED'],
#  ['오다'],
#  ['OLED'],
#  ['체감'],
#  ['대화'],
#  ['오브'],
#  ['쇼케이스'],
#  ['색상'],
#  ['왜곡'],
#  ['없이'],
#  ['표현'],
#  ['가능하다'],
#  ['디지털'],
#  ['캔버스'],
#  ['아트'],
#  ['캔버스'],
#  ['선보이다'],
#  ['향후'],
#  ['LG'],
#  ['디스플레이'],
#  ['늘다'],
#  ['스타트업'],
#  ['대상'],
#  ['새롭다'],
#  ['사업'],
#  ['기회'],
#  ['발굴'],
#  ['채다'],
#  ['린지'],
#  ['프로그램'],
#  ['펼치다'],
#  ['투명'],
#  ['OLED'],
#  ['OLED'],
#  ['오다'],
#  ['관련'],
#  ['새롭다'],
#  ['콘셉트'],
#  ['발굴'],
#  ['목표'],
#  ['11월'],
#  ['데모'],
#  ['데이'],
#  ['우수'],
#  ['업체'],
#  ['에는'],
#  ['제품'],
#  ['공동'],
#  ['개발'],
#  ['해외'],
#  ['전시회'],
#  ['참가'],
#  ['사업'],
#  ['확대'],
#  ['지원'],
#  ['LG'],
#  ['디스플레이'],
#  ['늘다'],
#  ['차별'],
#  ['OLED'],
#  ['기술'],
#  ['기반'],
#  ['국내외'],
#  ['고객'],
#  ['스타트업'],
#  ['과의'],
#  ['전략'],
#  ['협업'],
#  ['확대'],
#  ['통해'],
#  ['시장'],
#  ['추다'],
#  ['나가다'],
#  ['이라고'],
#  ['밝히다'],
#  ['폴리염화비닐'],
#  ['PVC'],
#  ['가장'],
#  ['흔하다'],
#  ['쓰이다'],
#  ['플라스틱'],
#  ['이다'],
#  ['PVC'],
#  ['에는'],
#  ['독성'],
#  ['많다'],
#  ['유해'],
#  ['물질'],
#  ['섞이다'],
#  ['제조'],
#  ['과정'],
#  ['안전하다'],
#  ['제거'],
#  ['중요하다'],
#  ['iR'],
#  ['52'],
#  ['장영실'],
#  ['자체'],
#  ['공법'],
#  ['유해'],
#  ['물질'],
#  ['효율'],
#  ['제거'],
#  ['PVC'],
#  ['제품'],
#  ['돌아가다'],
#  ['해당'],
#  ['제품'],
#  ['만들다'],
#  ['LG'],
#  ['화학'],
#  ['국내'],
#  ['무독'],
#  ['PVC'],
#  ['시장'],
#  ['이끌다'],
#  ['유아'],
#  ['장난감'],
#  ['이나'],
#  ['바닥재'],
#  ['실크'],
#  ['벽지'],
#  ['일상생활'],
#  ['소재'],
#  ['활용'],
#  ['PVC'],
#  ['늘다'],
#  ['휘발'],
#  ['유기화합물'],
#  ['VOC'],
#  ['Volatile'],
#  ['Organic'],
#  ['Compound'],
#  ['내포'],
#  ['VOC'],
#  ['늘다'],
#  ['독성'],
#  ['강하다'],
#  ['인체'],
#  ['오다'],
#  ['자연'],
#  ['해롭다'],
#  ['물질'],
#  ['제거'],
#  ['위해'],
#  ['LG'],
#  ['화학'],
#  ['중력'],
#  ['수십'],
#  ['수백'],
#  ['원심력'],
#  ['활용'],
#  ['플라스틱'],
#  ['수지'],
#  ['액막'],
#  ['형성'],
#  ['공정'],
#  ['기술'],
#  ['개발'],
#  ['수지'],
#  ['평면'],
#  ['놓다'],
#  ['강하다'],
#  ['회전'],
#  ['원심력'],
#  ['의하다'],
#  ['넓다'],
#  ['펴다'],
#  ['원리'],
#  ['상의'],
#  ['플라스틱'],
#  ['수지'],
#  ['얇다'],
#  ['수증기'],
#  ['가하다'],
#  ['VOC'],
#  ['오다'],
#  ['수증기'],
#  ['가다'],
#  ['서로'],
#  ['수지'],
#  ['VOC'],
#  ['가다'],
#  ['떨어지다'],
#  ['나가다'],
#  ['주은정'],
#  ['LG'],
#  ['화학'],
#  ['부장'],
#  ['물이'],
#  ['얇다'],
#  ['펴다'],
#  ['더욱'],
#  ['빠르다'],
#  ['증발'],
#  ['한다는'],
#  ['사실'],
#  ['착안'],
#  ['수지'],
#  ['넓다'],
#  ['펴다'],
#  ['회전'],
#  ['장치'],
#  ['개발'],
#  ['돼다'],
#  ['특히'],
#  ['장비'],
#  ['늘다'],
#  ['원심력'],
#  ['이용'],
#  ['수지'],
#  ['VOC'],
#  ['분리'],
#  ['때문'],
#  ['에너지'],
#  ['사용'],
#  ['최소'],
#  ['화하다'],
#  ['부장'],
#  ['원심력'],
#  ['바탕'],
#  ['수증기'],
#  ['더하다'],
#  ['VOC'],
#  ['가다'],
#  ['제거'],
#  ['때문'],
#  ['전체'],
#  ['공정'],
#  ['에너지'],
#  ['효율'],
#  ['기존'],
#  ['PVC'],
#  ['제품'],
#  ['생산'],
#  ['보다'],
#  ['80'],
#  ['가량'],
#  ['우수하다'],
#  ['강조'],
#  ['화학'],
#  ['제품'],
#  ['생산'],
#  ['장비'],
#  ['늘다'],
#  ['일정'],
#  ['주기'],
#  ['마다'],
#  ['장비'],
#  ['내부'],
#  ['청소'],
#  ['일도'],
#  ['중요하다'],
#  ['LG'],
#  ['화학'],
#  ['개발'],
#  ['장비'],
#  ['늘다'],
#  ['원심력'],
#  ['의하다'],
#  ['PVC'],
#  ['생산'],
#  ['때문'],
#  ['생산'],
#  ['설비'],
#  ['자체'],
#  ['청소'],
#  ['기능'],
#  ['갖추다'],
#  ['부장'],
#  ['에너지'],
#  ['용량'],
#  ['적다'],
#  ['고온'],
#  ['수지'],
#  ['가다'],
#  ['체류'],
#  ['짧다'],
#  ['약하다'],
#  ['PVC'],
#  ['품질'],
#  ['손상'],
#  ['최소'],
#  ['국제'],
#  ['우주정거장'],
#  ['ISS'],
#  ['중력'],
#  ['전혀'],
#  ['공간'],
#  ['미세하다'],
#  ['먼지'],
#  ['전자기파'],
#  ['일절'],
#  ['허용'],
#  ['특수하다'],
#  ['공간'],
#  ['이다'],
#  ['한국'],
#  ['과학자'],
#  ['들다'],
#  ['최소'],
#  ['수년'],
#  ['노력'],
#  ['만들다'],
#  ['우주과학'],
#  ['실험'],
#  ['기구'],
#  ['들다'],
#  ['치의'],
#  ['오차'],
#  ['없이'],
#  ['작동시키다'],
#  ['위해'],
#  ['최선'],
#  ['우주'],
#  ['에서의'],
#  ['과학'],
#  ['실험'],
#  ['최종'],
#  ['훈련'],
#  ['받다'],
#  ['위해'],
#  ['지난해'],
#  ['러시아'],
#  ['귀국'],
#  ['한국'],
#  ['우주인'],
#  ['후보'],
#  ['고산'],
#  ['후보'],
#  ['오다'],
#  ['이소연'],
#  ['후보'],
#  ['가다'],
#  ['훈련'],
#  ['첫날'],
#  ['2일'],
#  ['밝히다'],
#  ['각오'],
#  ['지난'],
#  ['연말'],
#  ['과학'],
#  ['행사'],
#  ['참여'],
#  ['한국'],
#  ['우주개발'],
#  ['사업'],
#  ['대한'],
#  ['홍보'],
#  ['활동'],
#  ['오다'],
#  ['들다'],
#  ['오다'],
#  ['10일'],
#  ['대덕'],
#  ['위치'],
#  ['한국'],
#  ['항공우주'],
#  ['연구원'],
#  ['우주인'],
#  ['발단'],
#  ['집중'],
#  ['훈련'],
#  ['받다'],
#  ['고산'],
#  ['후보'],
#  ['가다'],
#  ['오다'],
#  ['4월'],
#  ['ISS'],
#  ['8일'],
#  ['머물다'],
#  ['수행'],
#  ['실험'],
#  ['학생'],
#  ['들다'],
#  ['18'],
#  ['가지'],
#  ['고산'],
#  ['가다'],
#  ['얘기'],
#  ['처럼'],
#  ['우주'],
#  ['환경'],
#  ['지상'],
#  ['판이하다'],
#  ['과학'],
#  ['실험'],
#  ['기구'],
#  ['만들기'],
#  ['진동'],
#  ['소음'],
#  ['전자파'],
#  ['먼지'],
#  ['철저하다'],
#  ['제어'],
#  ['첨단'],
#  ['기술'],
#  ['필요하다'],
#  ['2000만달러'],
#  ['가다'],
#  ['소요'],
#  ['한국'],
#  ['우주인'],
#  ['배출'],
#  ['사업'],
#  ['실험'],
#  ['기구'],
#  ['만들다'],
#  ['한국'],
#  ['과학자'],
#  ['들다'],
#  ['고산'],
#  ['가다'],
#  ['이다'],
#  ['우주'],
#  ['에서의'],
#  ['실험'],
#  ['일반인'],
#  ['들다'],
#  ['생각'],
#  ['거리'],
#  ['가다'],
#  ['멀다'],
#  ['과학'],
#  ['실험'],
#  ['비커'],
#  ['스포이트'],
#  ['사용'],
#  ['무중력'],
#  ['상태'],
#  ['때문'],
#  ['실험'],
#  ['물질'],
#  ['노출'],
#  ['경우'],
#  ['공중'],
#  ['떠다니다'],
#  ['실험'],
#  ['실패'],
#  ['돌아가다'],
#  ['우주'],
#  ['실험'],
#  ['철저하다'],
#  ['밀폐'],
#  ['과학'],
#  ['키트'],
#  ['이루어지다'],
#  ['우주인'],
#  ['과학'],
#  ['키트'],
#  ['외부'],
#  ['버튼'],
#  ['누르다'],
#  ['자동'],
#  ['실험'],
#  ['진행'],
#  ['방식'],
#  ['이다'],
#  ['동의'],
#  ['경우'],
#  ['우주인'],
#  ['적절하다'],
#  ['조치'],
#  ['취하'],
#  ['늘다'],
#  ['구실'],
#  ['맡다'],
#  ['후보'],
#  ['가다'],
#  ['훈련'],
#  ['받다'],
#  ['실험'],
#  ['실습'],
#  ['우주'],
#  ['저울'],
#  ['우주'],
#  ['식품'],
#  ['실험'],
#  ['에도'],
#  ['키트'],
#  ['형태'],
#  ['기구'],
#  ['가다'],
#  ['사용'],
#  ['돼다'],
#  ['측정'],
#  ['물체'],
#  ['질량'],
#  ['지구'],
#  ['정확하다'],
#  ['측정'],
#  ['탑재'],
#  ['기준'],
#  ['질량'],
#  ['비교'],
#  ['방식'],
#  ['우주'],
#  ['공간'],
#  ['미세하다'],
#  ['질량'],
#  ['측정'],
#  ['가능하다'],
#  ['저울'],
#  ['실험'],
#  ['한국'],
#  ['처음'],
#  ['이다'],
#  ['고산'],
#  ['늘다'],
#  ['메모리'],
#  ['소자'],
#  ['기술'],
#  ['실험'],
#  ['우주'],
#  ['저울'],
#  ['실험'],
#  ['촉매'],
#  ['물질'],
#  ['합성'],
#  ['실험'],
#  ['대부분'],
#  ['자동'],
#  ['이루어지다'],
#  ['어렵다'],
#  ['식물'],
#  ['발아'],
#  ['오다'],
#  ['생장'],
#  ['관찰'],
#  ['실험'],
#  ['이나'],
#  ['초파리'],
#  ['이용'],
#  ['노화'],
#  ['유전자'],
#  ['탐색'],
#  ['작업'],
#  ['실험'],
#  ['자동화'],
#  ['가다'],
#  ['돼다'],
#  ['상대'],
#  ['난이도'],
#  ['가다'],
#  ['높다'],
#  ['과학'],
#  ['실험'],
#  ['곧장'],
#  ['기발하다'],
#  ['기술'],
#  ['이나'],
#  ['신제품'],
#  ['개발'],
#  ['활용'],
#  ['아직'],
#  ['우주'],
#  ['공간'],
#  ['에서의'],
#  ['경험'],
#  ['로서'],
#  ['늘다'],
#  ['난이도'],
#  ['실험'],
#  ['현실'],
#  ['어렵다'],
#  ['때문'],
#  ['이다'],
#  ['적절하다'],
#  ['결과'],
#  ['얻다'],
#  ['힘들다'],
#  ['리스크'],
#  ['가다'],
#  ['크다'],
#  ['실험'],
#  ['도전'],
#  ['실패하다'],
#  ['경우'],
#  ['실시'],
#  ['불가능하다'],
#  ['이다'],
#  ['한국'],
#  ['우주'],
#  ['실험'],
#  ['엄격하다'],
#  ['제한'],
#  ['러시아'],
#  ['통제'],
#  ['최기혁'],
#  ['항우연'],
#  ['우주인'],
#  ['발단'],
#  ['ISS'],
#  ['가져가다'],
#  ['과학'],
#  ['실험'],
#  ['도구'],
#  ['품목'],
#  ['러시아'],
#  ['엄격하다'],
#  ['기준'],
#  ['정해'],
#  ['놓다'],
#  ['실제'],
#  ['소유스'],
#  ['우주선'],
#  ['실리다'],
#  ['실험'],
#  ['도구'],
#  ['늘다'],
#  ['안정'],
#  ['테스트'],
#  ['위해'],
#  ['이미'],
#  ['차례'],
#  ['러시아'],
#  ['오가다'],
#  ...]
