# %% [markdown]
# # 전처리 연습 (Tokenize, Cleansing & Normalization, Stemming & Lemmatization)
#
# 1. 데이터셋(corpus)을 찾는다. (만들어진 데이터셋, 크롤링, ...)
#     - **🐿️ 이어지는 실습에 쓸 수 있을 법한 데이터 찾기 Tip**
#     - 여러 문장으로 이루어진 데이터셋이라면 일단 good
#         - 리뷰 등 이어지지 않는 짧은 문장 여러 건 ok
#         - 소설 등 이어지는 긴 문장 여러 건 ok
#     - 대화형 데이터셋도 good
#         - QnA로 구성되어 있는 corpus도 좋고
#         - 일반적인 대화로 구성되어 있는 corpus도 좋아요~
#     - 특정 도메인에 대한 정보를 담고 있는 데이터셋도 good
# 2. 전처리를 해본다.
#     - 텍스트 자체를 깔끔하게 만드는 것까지만

# %%
import os
import glob

# folder_path = "data/IT과학"
# output_file = "data/practice_뉴스_IT과학.txt"

# with open(output_file, "w", encoding="utf-8") as outfile:
#     for filepath in sorted(glob.glob(os.path.join(folder_path, "*.txt"))):
#         with open(filepath, "r", encoding="utf-8") as infile:
#             outfile.write(infile.read())
#             outfile.write("\n")

# %%
import pandas as pd
import re
path= "./data/IT과학/practice_뉴스_IT과학.txt"
raw = open(path, encoding="utf-8").read()

docs = [d.strip() for d in re.split(r"\n\s*\n+", raw) if d.strip()]
docs[:5]
# Out:
# ['LG디스플레이가 오는 11월 미국 새너제이에서 `오픈 이노베이션 포럼(Open Innovation Forum·OIF) 2022`의 일환으로  `챌린지 프로그램`을 연다.\n한국·미국 스타트업과 함께 디스플레이의 새로운 가치를 발굴하고 공동 사업을 추진하기 위한 포석이다.\n그동안 LG디스플레이는 투명 유기발광다이오드(OLED) 등에 새로운 가치를 부여하고자 이달 미국 라스베이거스에서 OIF를 열었다.\n이후 스타트업과 OLED 생태계 확대를 위해 과제 제안서 접수→1차 심사→사업화 검증(PoC)→미국 새너제이에서 데모데이→투자 검토를 순차적으로 진행할 방침이다.\nOIF는 스타트업을 포함한 산업 파트너와 함께 투명 OLED 솔루션 등에 대한 새로운 비전을 제시하기 위해 추진되고 있다.\nLG디스플레이는 `다양한 투명 OLED 솔루션을 통해 디스플레이를 혁신하겠다`면서 `이를 통해 디스플레이에 새로운 가치를 부여하고 시장 주도권을 유지하겠다`고 설명했다.\n이달 라스베이거스에서 열린 OIF 2022에선 수많은 투명 OLED 솔루션들을 선보였다.\n세계적인 건축 설계 업체 겐슬러와 손잡고 선보인 `사무용 투명 OLED 파티션`이 대표적이다.\n그동안 파티션은 공간 분리 기능만 있었지만, 파티션을 투명 OLED로 구성해 별도 모니터·TV가 없어도 즉석에서 영상회의와 프레젠테이션 등을 진행할 수 있도록 구성했다.\n파티션이 곧 모니터가 될 수 있는 셈이다.\n또 한국 인테리어 기업인 엑사이엔씨와 협업한 `회의실 투명 OLED 솔루션`을 선보였다.\n회의실에 있는 큰 유리 벽면을 투명 OLED로 구성해 벽면 전체를 디스플레이로 활용하도록 한 것이 특징이다.\n또 스타트업 다이어와 함께 벽면에 투명 OLED를 한 겹 덧붙여 사무실, 호텔, 병원 등에서 다양한 용도로 사용할 수 있는 디스플레이를 내놓았다.\nLG디스플레이는 고감도 터치 기능을 도입해 월패드나 미디어 갤러리로 사용이 가능한 `투명 갤러리`에 이어 `아이랩미디어`와의 협업으로 투명 OLED와 OLED를 결합해 입체감을 극대화한 `오브제 쇼케이스`, 색상 왜곡 없이 표현이 가능한 디지털 캔버스인 `아트 캔버스` 등을 선보였다.\n향후 LG디스플레이는 스타트업을 대상으로 새로운 사업 기회 발굴하고자 `챌린지 프로그램`을 펼친다.\n투명 OLED, OLED와 관련해 새로운 콘셉트를 발굴하는 것이 목표다.\n11월 데모데이를 열며 우수 업체에는 제품 공동 개발, 해외 전시회 참가 등 사업 확대를 지원한다.\n이에 대해 LG디스플레이는 `차별화된 OLED 기술 기반으로 국내외 고객사 및 스타트업과의 전략적 협업 확대를 통해 신시장을 창출해 나갈 것`이라고 밝혔다.\n미국 혁신의 상징 실리콘밸리에는 미국과 한국에 있는 한인 창업자들을 찾아 아낌없는 조언과 통 큰 투자를 해주는 선배 창업자가 있다.\n바로 프라이머사제파트너스의 이기하 대표(사진)다.\n프라이머사제의 `사제`는 `사제지간`을 뜻한다.\n단순히 자금만 대주는 벤처캐피털이 아닌 세계 진출의 징검다리 역할을 하고 선배 창업자들의 인적 네트워크를 제공하는 것을 표방한다.\n이기하 프라이머사제 대표는 매일경제와 만나 `스타트업 창업에 성공한 것이 입소문이 나면서 후배 창업자들이 찾아왔고 도움을 주다 보니 어느새 투자까지 하게 됐다`고 설명했다.\n그동안 프라이머사제의 투자를 받은 스타트업은 피스컬노트, 숨고, 데일리호텔, 호갱노노, 임프리메드 등 70곳에 달한다.\n이 대표는 10년 이상 스타트업을 운영하면서 단 한 차례도 투자를 받지 않았다.\n회사 수익으로만 회사를 운영하는 이른바 `부트스트래핑(Bootstrapping)`으로 성공한 셈이다.\n당시에는 투자 문화가 발달하지 않았고, 설령 받더라도 그 금액이 크지 않았다는 설명이다.\n그가 미국에 정착한 것은 외환위기 직후인 1999년으로 거슬러 올라간다.\n연세대 기계공학과 학사, 서울대 기계설계학과 석사를 마친 뒤 더 넓은 세상을 보고자 UC버클리로 유학을 갔다.\n이곳에서 그는 컴퓨터공학 석사와 기계공학 박사 학위를 받았다.\n이 대표는 `처음에는 교수가 꿈이었다`면서도 `하지만 2000년대가 넘어서자 웹2.0 시대가 활짝 펼쳐졌다`고 당시를 회고했다.\n웹2.0의 물결은 상상을 초월했다.\n웹2.0은 1.0과 달리 직접 콘텐츠를 제작하지 않고 타인이 올린 콘텐츠를 플랫폼 내에서 보여주는 새로운 시스템, 페이스북, 크레이그리스트, 구글, 플리커 등 급작스레 등장한 새로운 웹2.0 물결은 모든 것을 바꿨다.\n이 대표는 `구글은 그 어떠한 콘텐츠도 제작을 하지 않았지만 지구에 있는 모든 웹사이트를 자신의 브라우저에 보여주는 방식으로 이익을 극대화했다`면서 `구글에 있는 콘텐츠를 클릭하는 것만으로도 2000원씩 받는 것을 보고 엄청난 세상이 오는 것을 직감했다`고 말했다.\n창업을 하지 않을 수 없었다.\n이 대표가 웹페이지를 제작했고 배우자이자 디자이너인 김희지 씨가 디자인을 맡았다.\nJJ미디어라는 스타트업의 출발이었다.\n주변에 있는 한인 중소상인들의 홈페이지를 만들어 주는 업무였다.\n하지만 사업을 한 적이 없다 보니 순탄하지는 않았다.\n몇 차례 업종을 전환하는 피보팅(Pivoting)이 이어졌다.\n하지만 변신은 누구보다 빨랐다.\n김희지 씨는 `이 대표는 한 가지 일에 집중하는 성격이다 보니 몇 주면 새로운 웹페이지를 만들곤 했다`고 회고했다.\n뉴스를 모아서 보여주는 오크뉴스, 중고물품 플랫폼 코코베이, 각종 기업을 안내해주는 웹투리스트 등 2년간 6개에 달하는 서비스를 선보였다.\n하지만 큰 수익으로 이어지지는 않았다.\n이 대표는 `당시에는 수없이 많은 웹2.0 스타트업이 생겼다가 소리 소문 없이 사라졌다`면서 `어떻게 하면 이익을 낼까 고민하다가 마침내 찾은 것이 전자상거래였다`고 설명했다.\n딜스플러스의 창업이었다.\n딜스플러스는 가격이 저렴한 서비스나 제품인 이른바 `딜`을 보여주는 웹페이지였다.\n당초 사용자들이 스스로 발견한 `딜`들을 올릴 것이라고 생각을 했지만, 초기에는 아무도 올리지 않아 직접 딜을 찾아 올렸다.\n하지만 어느 순간 입소문이 나면서 사용자들이 직접 `딜`을 공유했다.\n매년 두 배씩 성장해 2012년이 되자 월간 트래픽이 1000만건씩 발생할 정도로 폭풍 성장했다.\n이 대표는 당시를 90대9대1의 법칙이 제대로 작동했다고 회고했다.\n그는 `방문자가 100명이라면 90명은 눈으로만 보고 9명은 소극적으로만 `좋아요`나 `댓글`만 달고 1명이 적극적으로 올리는 사람들`이라면서 `한때는 직원이 100명이 넘을 정도로 기업이 성장했다`고 전했다.\n소문을 듣고 2013년부터 후배 창업자들이 찾아오기 시작했다.\n조언도 해 주고 투자도 했다.\n데일리호텔, 호갱노노, 아이디어스 등이 대표적이다.\n2015년부터 후배 창업자들을 위해 체계적인 투자를 하고자 프라이머사제를 창업했다.\n그는 한인 스타트업 투자를 고집하는 이유에 대해 `한국인은 똑똑하다는 평가를 받지만, 한편으로는 절대 믿지 말고 사업도 같이하지 말라는 소리도 듣는다`면서 `미국이라는 큰 땅덩어리에서 생존과 성공을 위해 서로 도움을 주고받아도 모자랄 상황인데 안타까웠다`고 설명했다.\n오늘날 프라이머사제는 50만~300만달러를 서비스형 소프트웨어, 인공지능, 전자상거래, 핀데크, 헬스케어, 디지털 콘텐츠 스타트업에 투자한다.\n작년에는 약 1500억원 규모에 달하는 2차 펀드를 조성해 주목을 끌기도 했다.\n특히 유니콘 스타트업의 창업자들이 줄줄이 참여했다.\n눔의 정세주, 피스컬노트의 팀 황, 센드버드의 김동신, 타파스미디어의 김창원, 우아한형제들의 김봉진 등은 멘토로도 활동을 하고 있다.\n이 대표는 `향후 1조원에 달하는 자산을 운용하는 벤처캐피털로 거듭나겠다`면서 `미국에서 한인 창업자들의 성공은 이제 시작일 뿐`이라고 강조했다.\n숏폼 영상 자동 제작 솔루션 기업 비디오몬스터가 롱폼 영상 편집 애플리케이션 `비브(Viiv)`를 다음달 출시한다.\n전동혁 비디오몬스터 대표는 최근 매일경제와 만나 `비브 출시를 통해 비디오몬스터는 숏폼 영상과 롱폼 영상 모두 자동 제작하는 솔루션을 보유하게 됐다`면서 `이 솔루션을 통해 여행이나 브이로그 영상을 제작하려는 고객들 ...

# %%
import kss # 문장단위  , okt는 단어(형태소) 단위
from konlpy.tag import Okt

sample = docs[:5]
# sent = kss.split_sentences(sample) # kss는 문장 단위로 텍스트를 분할하는 라이브러리.

sample
# Out:
# ['LG디스플레이가 오는 11월 미국 새너제이에서 `오픈 이노베이션 포럼(Open Innovation Forum·OIF) 2022`의 일환으로  `챌린지 프로그램`을 연다.\n한국·미국 스타트업과 함께 디스플레이의 새로운 가치를 발굴하고 공동 사업을 추진하기 위한 포석이다.\n그동안 LG디스플레이는 투명 유기발광다이오드(OLED) 등에 새로운 가치를 부여하고자 이달 미국 라스베이거스에서 OIF를 열었다.\n이후 스타트업과 OLED 생태계 확대를 위해 과제 제안서 접수→1차 심사→사업화 검증(PoC)→미국 새너제이에서 데모데이→투자 검토를 순차적으로 진행할 방침이다.\nOIF는 스타트업을 포함한 산업 파트너와 함께 투명 OLED 솔루션 등에 대한 새로운 비전을 제시하기 위해 추진되고 있다.\nLG디스플레이는 `다양한 투명 OLED 솔루션을 통해 디스플레이를 혁신하겠다`면서 `이를 통해 디스플레이에 새로운 가치를 부여하고 시장 주도권을 유지하겠다`고 설명했다.\n이달 라스베이거스에서 열린 OIF 2022에선 수많은 투명 OLED 솔루션들을 선보였다.\n세계적인 건축 설계 업체 겐슬러와 손잡고 선보인 `사무용 투명 OLED 파티션`이 대표적이다.\n그동안 파티션은 공간 분리 기능만 있었지만, 파티션을 투명 OLED로 구성해 별도 모니터·TV가 없어도 즉석에서 영상회의와 프레젠테이션 등을 진행할 수 있도록 구성했다.\n파티션이 곧 모니터가 될 수 있는 셈이다.\n또 한국 인테리어 기업인 엑사이엔씨와 협업한 `회의실 투명 OLED 솔루션`을 선보였다.\n회의실에 있는 큰 유리 벽면을 투명 OLED로 구성해 벽면 전체를 디스플레이로 활용하도록 한 것이 특징이다.\n또 스타트업 다이어와 함께 벽면에 투명 OLED를 한 겹 덧붙여 사무실, 호텔, 병원 등에서 다양한 용도로 사용할 수 있는 디스플레이를 내놓았다.\nLG디스플레이는 고감도 터치 기능을 도입해 월패드나 미디어 갤러리로 사용이 가능한 `투명 갤러리`에 이어 `아이랩미디어`와의 협업으로 투명 OLED와 OLED를 결합해 입체감을 극대화한 `오브제 쇼케이스`, 색상 왜곡 없이 표현이 가능한 디지털 캔버스인 `아트 캔버스` 등을 선보였다.\n향후 LG디스플레이는 스타트업을 대상으로 새로운 사업 기회 발굴하고자 `챌린지 프로그램`을 펼친다.\n투명 OLED, OLED와 관련해 새로운 콘셉트를 발굴하는 것이 목표다.\n11월 데모데이를 열며 우수 업체에는 제품 공동 개발, 해외 전시회 참가 등 사업 확대를 지원한다.\n이에 대해 LG디스플레이는 `차별화된 OLED 기술 기반으로 국내외 고객사 및 스타트업과의 전략적 협업 확대를 통해 신시장을 창출해 나갈 것`이라고 밝혔다.\n미국 혁신의 상징 실리콘밸리에는 미국과 한국에 있는 한인 창업자들을 찾아 아낌없는 조언과 통 큰 투자를 해주는 선배 창업자가 있다.\n바로 프라이머사제파트너스의 이기하 대표(사진)다.\n프라이머사제의 `사제`는 `사제지간`을 뜻한다.\n단순히 자금만 대주는 벤처캐피털이 아닌 세계 진출의 징검다리 역할을 하고 선배 창업자들의 인적 네트워크를 제공하는 것을 표방한다.\n이기하 프라이머사제 대표는 매일경제와 만나 `스타트업 창업에 성공한 것이 입소문이 나면서 후배 창업자들이 찾아왔고 도움을 주다 보니 어느새 투자까지 하게 됐다`고 설명했다.\n그동안 프라이머사제의 투자를 받은 스타트업은 피스컬노트, 숨고, 데일리호텔, 호갱노노, 임프리메드 등 70곳에 달한다.\n이 대표는 10년 이상 스타트업을 운영하면서 단 한 차례도 투자를 받지 않았다.\n회사 수익으로만 회사를 운영하는 이른바 `부트스트래핑(Bootstrapping)`으로 성공한 셈이다.\n당시에는 투자 문화가 발달하지 않았고, 설령 받더라도 그 금액이 크지 않았다는 설명이다.\n그가 미국에 정착한 것은 외환위기 직후인 1999년으로 거슬러 올라간다.\n연세대 기계공학과 학사, 서울대 기계설계학과 석사를 마친 뒤 더 넓은 세상을 보고자 UC버클리로 유학을 갔다.\n이곳에서 그는 컴퓨터공학 석사와 기계공학 박사 학위를 받았다.\n이 대표는 `처음에는 교수가 꿈이었다`면서도 `하지만 2000년대가 넘어서자 웹2.0 시대가 활짝 펼쳐졌다`고 당시를 회고했다.\n웹2.0의 물결은 상상을 초월했다.\n웹2.0은 1.0과 달리 직접 콘텐츠를 제작하지 않고 타인이 올린 콘텐츠를 플랫폼 내에서 보여주는 새로운 시스템, 페이스북, 크레이그리스트, 구글, 플리커 등 급작스레 등장한 새로운 웹2.0 물결은 모든 것을 바꿨다.\n이 대표는 `구글은 그 어떠한 콘텐츠도 제작을 하지 않았지만 지구에 있는 모든 웹사이트를 자신의 브라우저에 보여주는 방식으로 이익을 극대화했다`면서 `구글에 있는 콘텐츠를 클릭하는 것만으로도 2000원씩 받는 것을 보고 엄청난 세상이 오는 것을 직감했다`고 말했다.\n창업을 하지 않을 수 없었다.\n이 대표가 웹페이지를 제작했고 배우자이자 디자이너인 김희지 씨가 디자인을 맡았다.\nJJ미디어라는 스타트업의 출발이었다.\n주변에 있는 한인 중소상인들의 홈페이지를 만들어 주는 업무였다.\n하지만 사업을 한 적이 없다 보니 순탄하지는 않았다.\n몇 차례 업종을 전환하는 피보팅(Pivoting)이 이어졌다.\n하지만 변신은 누구보다 빨랐다.\n김희지 씨는 `이 대표는 한 가지 일에 집중하는 성격이다 보니 몇 주면 새로운 웹페이지를 만들곤 했다`고 회고했다.\n뉴스를 모아서 보여주는 오크뉴스, 중고물품 플랫폼 코코베이, 각종 기업을 안내해주는 웹투리스트 등 2년간 6개에 달하는 서비스를 선보였다.\n하지만 큰 수익으로 이어지지는 않았다.\n이 대표는 `당시에는 수없이 많은 웹2.0 스타트업이 생겼다가 소리 소문 없이 사라졌다`면서 `어떻게 하면 이익을 낼까 고민하다가 마침내 찾은 것이 전자상거래였다`고 설명했다.\n딜스플러스의 창업이었다.\n딜스플러스는 가격이 저렴한 서비스나 제품인 이른바 `딜`을 보여주는 웹페이지였다.\n당초 사용자들이 스스로 발견한 `딜`들을 올릴 것이라고 생각을 했지만, 초기에는 아무도 올리지 않아 직접 딜을 찾아 올렸다.\n하지만 어느 순간 입소문이 나면서 사용자들이 직접 `딜`을 공유했다.\n매년 두 배씩 성장해 2012년이 되자 월간 트래픽이 1000만건씩 발생할 정도로 폭풍 성장했다.\n이 대표는 당시를 90대9대1의 법칙이 제대로 작동했다고 회고했다.\n그는 `방문자가 100명이라면 90명은 눈으로만 보고 9명은 소극적으로만 `좋아요`나 `댓글`만 달고 1명이 적극적으로 올리는 사람들`이라면서 `한때는 직원이 100명이 넘을 정도로 기업이 성장했다`고 전했다.\n소문을 듣고 2013년부터 후배 창업자들이 찾아오기 시작했다.\n조언도 해 주고 투자도 했다.\n데일리호텔, 호갱노노, 아이디어스 등이 대표적이다.\n2015년부터 후배 창업자들을 위해 체계적인 투자를 하고자 프라이머사제를 창업했다.\n그는 한인 스타트업 투자를 고집하는 이유에 대해 `한국인은 똑똑하다는 평가를 받지만, 한편으로는 절대 믿지 말고 사업도 같이하지 말라는 소리도 듣는다`면서 `미국이라는 큰 땅덩어리에서 생존과 성공을 위해 서로 도움을 주고받아도 모자랄 상황인데 안타까웠다`고 설명했다.\n오늘날 프라이머사제는 50만~300만달러를 서비스형 소프트웨어, 인공지능, 전자상거래, 핀데크, 헬스케어, 디지털 콘텐츠 스타트업에 투자한다.\n작년에는 약 1500억원 규모에 달하는 2차 펀드를 조성해 주목을 끌기도 했다.\n특히 유니콘 스타트업의 창업자들이 줄줄이 참여했다.\n눔의 정세주, 피스컬노트의 팀 황, 센드버드의 김동신, 타파스미디어의 김창원, 우아한형제들의 김봉진 등은 멘토로도 활동을 하고 있다.\n이 대표는 `향후 1조원에 달하는 자산을 운용하는 벤처캐피털로 거듭나겠다`면서 `미국에서 한인 창업자들의 성공은 이제 시작일 뿐`이라고 강조했다.\n숏폼 영상 자동 제작 솔루션 기업 비디오몬스터가 롱폼 영상 편집 애플리케이션 `비브(Viiv)`를 다음달 출시한다.\n전동혁 비디오몬스터 대표는 최근 매일경제와 만나 `비브 출시를 통해 비디오몬스터는 숏폼 영상과 롱폼 영상 모두 자동 제작하는 솔루션을 보유하게 됐다`면서 `이 솔루션을 통해 여행이나 브이로그 영상을 제작하려는 고객들 ...

# %%
# okt = Okt()
# tokens_morphs = okt.morphs(docs[0]) # morphs는 형태소 단위로 토큰화
# texts = okt.morphs(raw)
# texts
# print(texts)

# %%
ko_stopwords = set("아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼	어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다	하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영".split())
okt = Okt()
# clean_tokens = [token for token in tokens if token not in ko_stopwords]
preprocessed_tokens = []

for doc in docs:
    tokens = okt.pos(doc, stem=True) 

    tokens = [word for word, pos in tokens if pos in ['Noun']]
    tokens = [t for t in tokens if t not in ko_stopwords]
    tokens = [re.sub(r"[^가-힣A-Za-z0-9]+", "", t) for t in tokens]
    tokens = [t for t in tokens if t]  # 빈 문자열 제거
    tokens = [t for t in tokens if len(t) > 1]  # 길이 1 이하 토큰 제거
    tokens = [t for t in tokens if not t.isdigit()] # 숫자만 있는거 제거

    if tokens:  # 빈 리스트 제외
        preprocessed_tokens.append(tokens)

# %%
preprocessed_tokens
# Out:
# [['디스플레이',
#   '미국',
#   '새너제이',
#   '오픈',
#   '이노베이션',
#   '포럼',
#   '일환',
#   '린지',
#   '프로그램',
#   '한국',
#   '미국',
#   '스타트업',
#   '디스플레이',
#   '가치',
#   '발굴',
#   '공동',
#   '사업',
#   '추진',
#   '포석',
#   '그동안',
#   '디스플레이',
#   '투명',
#   '유기발광다이오드',
#   '가치',
#   '부여',
#   '미국',
#   '라스베이거스',
#   '이후',
#   '스타트업',
#   '생태계',
#   '확대',
#   '위해',
#   '과제',
#   '제안',
#   '접수',
#   '심사',
#   '사업',
#   '검증',
#   '미국',
#   '새너제이',
#   '데모',
#   '데이',
#   '투자',
#   '검토',
#   '순차',
#   '진행',
#   '방침',
#   '스타트업',
#   '포함',
#   '산업',
#   '파트너',
#   '투명',
#   '솔루션',
#   '대한',
#   '제시',
#   '위해',
#   '추진',
#   '디스플레이',
#   '투명',
#   '솔루션',
#   '통해',
#   '디스플레이',
#   '혁신',
#   '면서',
#   '통해',
#   '디스플레이',
#   '가치',
#   '부여',
#   '시장',
#   '주도',
#   '유지',
#   '설명',
#   '라스베이거스',
#   '투명',
#   '솔루션',
#   '세계',
#   '건축',
#   '설계',
#   '업체',
#   '겐슬러',
#   '무용',
#   '투명',
#   '파티션',
#   '대표',
#   '그동안',
#   '파티션',
#   '공간',
#   '분리',
#   '기능',
#   '파티션',
#   '투명',
#   '구성',
#   '별도',
#   '모니터',
#   '즉석',
#   '영상',
#   '회의',
#   '프레',
#   '테이',
#   '진행',
#   '구성',
#   '파티션',
#   '모니터',
#   '한국',
#   '인테리어',
#   '기업인',
#   '엑사',
#   '엔씨',
#   '협업',
#   '회의실',
#   '투명',
#   '솔루션',
#   '회의실',
#   '유리',
#   '벽면',
#   '투명',
#   '구성',
#   '벽면',
#   '전체',
#   '디스플레이',
#   '활용',
#   '특징',
#   '스타트업',
#   '벽면',
#   '투명',
#   '사무실',
#   '호텔',
#   '병원',
#   '용도',
#   '사용',
#   '디스플레이',
#   '디스플레이',
#   '터치',
#   '기능',
#   '도입',
#   '패드',
#   '미디어',
#   '갤러리',
#   '사용',
#   '투명',
#   '갤러리',
#   '미디어',
#   '협업',
#   '투명',
#   '체감',
#   '대화',
#   '오브',
#   '쇼케이스',
#   '색상',
#   '왜곡',
#   '표현',
#   '디지털',
#   '캔버스',
#   '아트',
#   '캔버스',
#   '향후',
#   '디스플레이',
#   '스타트업',
#   '대상',
#   '사업',
#   '기회',
#   '발굴',
#   '린지',
#   '프로그램',
#   '투명',
#   '관련',
#   '콘셉트',
#   '발굴',
#   '목표',
#   '데모',
#   '데이',
#   '우수',
#   '업체',
#   '제품',
#   '공동',
#   '개발',
#   '해외',
#   '전시회',
#   '참가',
#   '사업',
#   '확대',
#   '지원',
#   '디스플레이',
#   '차별',
#   '기술',
#   '기반',
#   '국내외',
#   '고객',
#   '스타트업',
#   '전략',
#   '협업',
#   '확대',
#   '통해',
#   '시장',
#   '미국',
#   '혁신',
#   '상징',
#   '실리콘밸리',
#   '미국',
#   '한국',
#   '한인',
#   '창업',
#   '조언',
#   '투자',
#   '선배',
#   '창업',
#   '프라이머',
#   '파트너',
#   '이기하',
#   '대표',
#   '사진',
#   '프라이머',
#   '제의',
#   '사제',
#   '제지',
#   '자금',
#   '대주',
#   '벤처캐피털',
#   '세계',
#   '진출',
#   '역할',
#   '선배',
#   '창업',
#   '인적',
#   '네트워크',
#   '제공',
#   '표방',
#   '이기하',
#   '프라이머',
#   '사제',
#   '대표',
#   '매일경제',
#   '스타트업',
#   '창업',
#   '소문',
#   '후배',
#   '창업',
#   '도움',
#   '투자',
#   '설명',
#   '그동안',
#   '프라이머',
#   '제의',
#   '투자',
#   '스타트업',
#   '스컬',
#   '노트',
#   '일리',
#   '호텔',
#   '호갱',
#   '노노',
#   '프리',
#   '메드',
#   '대표',
#   '스타트업',
#   '운영',
#   '차례',
#   '투자',
#   '회사',
#   '수익',
#   '회사',
#   '운영',
#   '부트스트래핑',
#   '당시',
#   '투자',
#   '문화',
#   '발달',
#   '금액',
#   '설명',
#   '미국',
#   '정착',
#   '외환위기',
#   '직후',
#   '거슬러',
#   '연세대',
#   '기계공학',
#   '학사',
#   '서울대',
#   '기계설계',
#   '학과',
#   '석사',
#   '세상',
#   '보고',
#   '버클리',
#   '유학',
#   '컴퓨터공학',
#   '석사',
#   '기계공학',
#   '박사',
#   '학위',
#   '대표',
#   '처음',
#   '교수',
#   '시대',
#   '활짝',
#   '당시',
#   '회고',
#   '물결',
#   '상상',
#   '초월',
#   '달리',
#   '직접',
#   '콘텐츠',
#   '제작',
#   '콘텐츠',
#   '플랫폼',
#   '시스템',
#   '페이스북',
#   '크레이그리스트',
#   '구글',
#   '플리커',
#   '급작스레',
#   '등장',
#   '물결',
#   '모든',
#   '대표',
#   '구글',
#   '콘텐츠',
#   '제작',
#   '지구',
#   '모든',
#   '웹사이트',
#   '브라우저',
#   '방식',
#   '이익',
#   '극대',
#   '면서',
#   '구글',
#   '콘텐츠',
#   '클릭',
#   '보고',
#   '세상',
#   '직감',
#   '창업',
#   '대표',
#   '웹페이지',
#   '제작',
#   '배우자',
#   '이자',
#   '디자이너',
#   '김희지',
#   '디자인',
#   '미디어',
#   '스타트업',
#   '출발',
#   '주변',
#   '한인',
#   '중소',
#   '상인',
#   '홈페이지',
#   '업무',
#   '사업',
#   '순탄',
#   '차례',
#   '업종',
#   '전환',
#   '피보팅',
#   '변신',
#   '김희지',
#   '대표',
#   '가지',
#   '집중',
#   '성격',
#   '웹페이지',
#   '회고',
#   '뉴스',
#   '오크',
#   '뉴스',
#   '중고',
#   '물품',
#   '플랫폼',
#   '코코',
#   '베이',
#   '기업',
#   '안내',
#   '웹투',
#   '리스트',
#   '서비스',
#   '수익',
#   '대표',
#   '당시',
#   '스타트업',
#   '소리',
#   '소문',
#   '면서',
#   '이익',
#   '고민',
#   '마침내',
#   '전자상거래',
#   '설명',
#   '딜스',
#   '플러스',
#   '창업',
#   '딜스',
#   '플러스',
#   '가격',
#   '서비스',
#   '제품',
#   '웹페이지',
#   '당초',
#   '사용자',
#   '스스로',
#   '발견',
#   '생각',
#   '초기',
#   '아무',
#   '리지',
#   '직접',
#   '순간',
#   '소문',
#   '사용자',
#   '직접',
#   '공유',
#   '매년',
#   '월간',
#   '트래픽',
#   '발생',
#   '정도',
#   '폭풍',
#   '대표',
#   '당시',
#   '법칙',
#   '제대로',
#   '작동',
#   '회고',
#   '방문자',
#   '라면',
#   '보고',
#   '극적',
#   '댓글',
#   '적극',
#   '사람',
#   '직원',
#   '정도',
#   '기업',
#   '소문',
#   '후배',
#   '창업',
#   '시작',
#   '조언',
#   '투자',
#   '일리',
#   '호텔',
#   '호갱',
#   '노노',
#   '아이디',
#   '어스',
#   '대표',
#   '후배',
#   '창업',
#   '위해',
#   '체계',
#   '투자',
#   '프라이머',
#   '사제',
#   '창업',
#   '한인',
#   '스타트업',
#   '투자',
#   '고집',
#   '이유',
#   '한국인',
#   '평가',
#   '한편',
#   '절대',
#   '사업',
#   '소리',
#   '면서',
#   '미국',
#   '덩어리',
#   '생존',
#   '성공',
#   '위해',
#   '서로',
#   '도움',
#   '상황',
#   '설명',
#   '오늘날',
#   '프라이머',
#   '사제',
#   '서비스',
#   '소프트웨어',
#   '인공',
#   '지능',
#   '전자상거래',
#   '데크',
#   '스케',
#   '디지털',
#   '콘텐츠',
#   '스타트업',
#   '투자',
#   '작년',
#   '규모',
#   '펀드',
#   '조성',
#   '주목',
#   '기도',
#   '유니콘',
#   '스타트업',
#   '창업',
#   '줄줄이',
#   '참여',
#   '정세주',
#   '스컬',
#   '노트',
#   '센드버드',
#   '김동신',
#   '타파스',
#   '미디어',
#   '김창원',
#   '형제',
#   '김봉진',
#   '토로',
#   '활동',
#   '대표',
#   '향후',
#   '자산',
#   '운용',
#   '벤처캐피털',
#   '거듭',
#   '면서',
#   '미국',
#   '한인',
#   '창업',
#   '성공',
#   '이제',
#   '작일',
#   '강조',
#   '숏폼',
#   '영상',
#   '자동',
#   '제작',
#   '솔루션',
#   '기업',
#   '비디오',
#   '몬스터',
#   '롱폼',
#   '영상',
#   '편집',
#   '애플리케이션',
#   '비브',
#   '출시',
#   '비디오',
#   '몬스터',
#   '대표',
#   '최근',
#   '매일경제',
#   '비브',
#   '출시',
#   '통해',
#   '비디오',
#   '몬스터',
#   '숏폼',
#   '영상',
#   '롱폼',
#   '영상',
#   '자동',
#   '제작',
#   '솔루션',
#   '보유',
#   '면서',
#   '솔루션',
#   '통해',
#   '여행',
#   '브이',
#   '로그',
#   '영상',
#   '제작',
#   '고객',
#   '공략',
#   '비브',
#   '촬영',
#   '자동',
#   '영상',
#   '편집',
#   '솔루션',
#   '비디오',
#   '몬스터',
#   '이미지',
#   '영상',
#   '인물',
#   '동물',
#   '음식',
#   '배경',
#   '객체',
#   '정보',
#   '인식',
#   '촬영',
#   '장소',
#   '정보',
#   '분석',
#   '이미지',
#   '태깅',
#   '태깅된',
#   '메타데이터',
#   '기반',
#   '영상',
#   '자동',
#   '편집',
#   '기술',
#   '개발',
#   '잘못',
#   '이미지',
#   '영상',
#   '자동',
#   '배제',
#   '이미지',
#   '영상',
#   '배경',
#   '전환',
#   '효과',
#   '부여',
#   '촬영',
#   '자의',
#   '얼굴',
#   '통해',
#   '성과',
#   '연령',
#   '추측',
#   '음악',
#   '폰트',
#   '자동',
#   '추천',
#   '이미지',
#   '영상',
#   '분량',
#   '렌더링',
#   '영상',
#   '대표',
#   '이미지',
#   '영상',
#   '맥락',
#   '추론',
#   '자동',
#   '편집',
#   '때문',
#   '사용',
#   '완성',
#   '영상',
#   '유튜브',
#   '인스타그램',
#   '소셜미디어',
#   '공유',
#   '비브',
#   '여행',
#   '브이',
#   '로그',
#   '영상',
#   '제작',
#   '관심',
#   '세대',
#   '사용',
#   '타깃',
#   '비디오',
#   '몬스터',
#   '사용자',
#   '영상',
#   '객체',
#   '정보',
#   '위치',
#   '정보',
#   '활용',
#   '사업',
#   '전개',
#   '계획',
#   '브로',
#   '영상',
#   '현재',
#   '사용자',
#   '위치',
#   '정보',
#   '때문',
#   '맛집',
#   '호텔',
#   '스팟',
#   '실시간',
#   '공유',
#   '레이',
#   '콘텐츠',
#   '희망',
#   '여행지',
#   '폴로',
#   '해당',
#   '지역',
#   '영상',
#   '공유',
#   '광고',
#   '여행',
#   '상품',
#   '비디오',
#   '몬스터',
#   '마케팅',
#   '사회',
#   '관계',
#   '서비스',
#   '최적화',
#   '내외',
#   '숏폼',
#   '영상',
#   '제작',
#   '플랫폼',
#   '비디오',
#   '몬스터',
#   '먼저',
#   '시작',
#   '전문',
#   '지식',
#   '영상',
#   '제작',
#   '래그',
#   '앤드',
#   '드롭',
#   '방식',
#   '적용',
#   '영상',
#   '가장',
#   '디자인',
#   '템플릿',
#   '자동',
#   '추천',
#   '때문',
#   '디자인',
#   '능력',
#   '사진',
#   '플랫폼',
#   '검색',
#   '삽입',
#   '폰트',
#   '영상',
#   '분위기',
#   '선택',
#   '영상',
#   '비율',
#   '유튜브',
#   '용인',
#   '비율',
#   '모바일',
#   '용인',
#   '비율',
#   '선택',
#   '대표',
#   '이용자',
#   '콘텐츠',
#   '시대',
#   '소비자',
#   '영상',
#   '기업',
#   '홍보',
#   '영상',
#   '반응',
#   '단순',
#   '편집',
#   '제공',
#   '디자인',
#   '테마',
#   '템플릿',
#   '제공',
#   '방식',
#   '영상',
#   '제작',
#   '변화',
#   '비디오',
#   '몬스터',
#   '영상',
#   '제작',
#   '비용',
#   '획기',
#   '절감',
#   '비디오',
#   '몬스터',
#   '영상',
#   '제작',
#   '템플릿',
#   '저작권',
#   '해결',
#   '이미지',
#   '음원',
#   '지원',
#   '클라우드',
#   '기반',
#   '자동',
#   '렌더링',
#   '엔진',
#   '초보자',
#   '퍼포먼스',
#   '영상',
#   '제작',
#   '현재',
#   '제품',
#   '사진',
#   '등록',
#   '템플릿',
#   '매칭',
#   '인공',
#   '지능',
#   '자동',
#   '추천',
#   '솔루션',
#   '개발',
#   '중이',
#   '비디오',
#   '몬스터',
#   '숏폼',
#   '영상',
#   '솔루션',
#   '비디오',
#   '몬스터',
#   '고객',
#   '상공',
#   '소규모',
#   '업주',
#   '지속',
#   '확대',
#   '롱폼',
#   '영상',
#   '제작',
#   '솔루션',
#   '비브',
#   '사용자',
#   '일반인',
#   '유입',
#   '사업',
#   '시너지',
#   '효과',
#   '사용자',
#   '확대',
#   '기반',
#   '비디오',
#   '몬스터',
#   '글로벌',
#   '진출',
#   '가속',
#   '계획',
#   '비디오',
#   '몬스터',
#   '지난해',
#   '해외',
#   '진출',
#   '개월',
#   '월간',
#   '이용',
#   '자수',
#   '달성',
#   '대표',
#   '영상',
#   '제작',
#   '업무',
#   '영상',
#   '전문가',
#   '비디오',
#   '몬스터',
#   '법인',
#   '설립',
#   '서비스',
#   '상반기',
#   '규모',
#   '시리즈',
#   '투자',
#   '유치',
#   '완료',
#   '이노',
#   '폴리스',
#   '파트너',
#   '스마트',
#   '스터디',
#   '벤처스',
#   '홀딩스',
#   '유니온',
#   '파트너',
#   '참여',
#   '비브',
#   '출시',
#   '하반기',
#   '시리즈',
#   '계획',
#   '스마트폰',
#   '자동차',
#   '연결',
#   '기술',
#   '세상',
#   '차량',
#   '스마트',
#   '스마트폰',
#   '갤럭시',
#   '울트라',
#   '차량',
#   '디지털',
#   '서비스',
#   '제공',
#   '스마트폰',
#   '생활',
#   '예고',
#   '디지털',
#   '초광대역',
#   '주파수',
#   '이용',
#   '정밀',
#   '위치',
#   '측정',
#   '기술',
#   '적용',
#   '기술',
#   '디지털',
#   '기존',
#   '스마트',
#   '마찬가지',
#   '주머니',
#   '스마트폰',
#   '작동',
#   '스마트폰',
#   '차량',
#   '차량',
#   '디지털',
#   '미리',
#   '등록',
#   '스마트폰',
#   '위치',
#   '인식',
#   '사용자',
#   '차량',
#   '해제',
#   '기술',
#   '적용',
#   '디지털',
#   '지원',
#   '제품',
#   '갤럭시',
#   '갤럭시',
#   '울트라',
#   '갤럭시',
#   '폴드',
#   '갤럭시',
#   '갤럭시',
#   '울트라',
#   '갤럭시',
#   '폴드',
#   '갤럭시',
#   '노트',
#   '울트라',
#   '종이',
#   '디지털',
#   '서비스',
#   '지원',
#   '패스',
#   '지문',
#   '생체',
#   '정보',
#   '사용',
#   '로그인',
#   '보안',
#   '기반',
#   '인증',
#   '플랫폼',
#   '패스',
#   '공공기관',
#   '서비스',
#   '이용',
#   '전자서명',
#   '인증서',
#   '비밀번호',
#   '형태',
#   '개인정보',
#   '통합',
#   '관리',
#   '웹사이트',
#   '로그인',
#   '모바일',
#   '뱅킹',
#   '사용',
#   '비밀번호',
#   '입력',
#   '액세스',
#   '사용자',
#   '추가',
#   '디지털',
#   '개인정보',
#   '관리',
#   '출시',
#   '지갑',
#   '플랫폼',
#   '삼성',
#   '월렛',
#   '디지털',
#   '기능',
#   '지원',
#   '예정',
#   '사용자',
#   '월렛',
#   '업데이트',
#   '디지털',
#   '사용',
#   '패스',
#   '디지털',
#   '사용',
#   '발급',
#   '먼저',
#   '현대차',
#   '제네시스',
#   '커넥티드',
#   '서비스',
#   ...]]

# %%
preprocessed_texts = [" ".join(tokens) for tokens in preprocessed_tokens]

# %%
preprocessed_texts
# Out:
# ['디스플레이 미국 새너제이 오픈 이노베이션 포럼 일환 린지 프로그램 한국 미국 스타트업 디스플레이 가치 발굴 공동 사업 추진 포석 그동안 디스플레이 투명 유기발광다이오드 가치 부여 미국 라스베이거스 이후 스타트업 생태계 확대 위해 과제 제안 접수 심사 사업 검증 미국 새너제이 데모 데이 투자 검토 순차 진행 방침 스타트업 포함 산업 파트너 투명 솔루션 대한 제시 위해 추진 디스플레이 투명 솔루션 통해 디스플레이 혁신 면서 통해 디스플레이 가치 부여 시장 주도 유지 설명 라스베이거스 투명 솔루션 세계 건축 설계 업체 겐슬러 무용 투명 파티션 대표 그동안 파티션 공간 분리 기능 파티션 투명 구성 별도 모니터 즉석 영상 회의 프레 테이 진행 구성 파티션 모니터 한국 인테리어 기업인 엑사 엔씨 협업 회의실 투명 솔루션 회의실 유리 벽면 투명 구성 벽면 전체 디스플레이 활용 특징 스타트업 벽면 투명 사무실 호텔 병원 용도 사용 디스플레이 디스플레이 터치 기능 도입 패드 미디어 갤러리 사용 투명 갤러리 미디어 협업 투명 체감 대화 오브 쇼케이스 색상 왜곡 표현 디지털 캔버스 아트 캔버스 향후 디스플레이 스타트업 대상 사업 기회 발굴 린지 프로그램 투명 관련 콘셉트 발굴 목표 데모 데이 우수 업체 제품 공동 개발 해외 전시회 참가 사업 확대 지원 디스플레이 차별 기술 기반 국내외 고객 스타트업 전략 협업 확대 통해 시장 미국 혁신 상징 실리콘밸리 미국 한국 한인 창업 조언 투자 선배 창업 프라이머 파트너 이기하 대표 사진 프라이머 제의 사제 제지 자금 대주 벤처캐피털 세계 진출 역할 선배 창업 인적 네트워크 제공 표방 이기하 프라이머 사제 대표 매일경제 스타트업 창업 소문 후배 창업 도움 투자 설명 그동안 프라이머 제의 투자 스타트업 스컬 노트 일리 호텔 호갱 노노 프리 메드 대표 스타트업 운영 차례 투자 회사 수익 회사 운영 부트스트래핑 당시 투자 문화 발달 금액 설명 미국 정착 외환위기 직후 거슬러 연세대 기계공학 학사 서울대 기계설계 학과 석사 세상 보고 버클리 유학 컴퓨터공학 석사 기계공학 박사 학위 대표 처음 교수 시대 활짝 당시 회고 물결 상상 초월 달리 직접 콘텐츠 제작 콘텐츠 플랫폼 시스템 페이스북 크레이그리스트 구글 플리커 급작스레 등장 물결 모든 대표 구글 콘텐츠 제작 지구 모든 웹사이트 브라우저 방식 이익 극대 면서 구글 콘텐츠 클릭 보고 세상 직감 창업 대표 웹페이지 제작 배우자 이자 디자이너 김희지 디자인 미디어 스타트업 출발 주변 한인 중소 상인 홈페이지 업무 사업 순탄 차례 업종 전환 피보팅 변신 김희지 대표 가지 집중 성격 웹페이지 회고 뉴스 오크 뉴스 중고 물품 플랫폼 코코 베이 기업 안내 웹투 리스트 서비스 수익 대표 당시 스타트업 소리 소문 면서 이익 고민 마침내 전자상거래 설명 딜스 플러스 창업 딜스 플러스 가격 서비스 제품 웹페이지 당초 사용자 스스로 발견 생각 초기 아무 리지 직접 순간 소문 사용자 직접 공유 매년 월간 트래픽 발생 정도 폭풍 대표 당시 법칙 제대로 작동 회고 방문자 라면 보고 극적 댓글 적극 사람 직원 정도 기업 소문 후배 창업 시작 조언 투자 일리 호텔 호갱 노노 아이디 어스 대표 후배 창업 위해 체계 투자 프라이머 사제 창업 한인 스타트업 투자 고집 이유 한국인 평가 한편 절대 사업 소리 면서 미국 덩어리 생존 성공 위해 서로 도움 상황 설명 오늘날 프라이머 사제 서비스 소프트웨어 인공 지능 전자상거래 데크 스케 디지털 콘텐츠 스타트업 투자 작년 규모 펀드 조성 주목 기도 유니콘 스타트업 창업 줄줄이 참여 정세주 스컬 노트 센드버드 김동신 타파스 미디어 김창원 형제 김봉진 토로 활동 대표 향후 자산 운용 벤처캐피털 거듭 면서 미국 한인 창업 성공 이제 작일 강조 숏폼 영상 자동 제작 솔루션 기업 비디오 몬스터 롱폼 영상 편집 애플리케이션 비브 출시 비디오 몬스터 대표 최근 매일경제 비브 출시 통해 비디오 몬스터 숏폼 영상 롱폼 영상 자동 제작 솔루션 보유 면서 솔루션 통해 여행 브이 로그 영상 제작 고객 공략 비브 촬영 자동 영상 편집 솔루션 비디오 몬스터 이미지 영상 인물 동물 음식 배경 객체 정보 인식 촬영 장소 정보 분석 이미지 태깅 태깅된 메타데이터 기반 영상 자동 편집 기술 개발 잘못 이미지 영상 자동 배제 이미지 영상 배경 전환 효과 부여 촬영 자의 얼굴 통해 성과 연령 추측 음악 폰트 자동 추천 이미지 영상 분량 렌더링 영상 대표 이미지 영상 맥락 추론 자동 편집 때문 사용 완성 영상 유튜브 인스타그램 소셜미디어 공유 비브 여행 브이 로그 영상 제작 관심 세대 사용 타깃 비디오 몬스터 사용자 영상 객체 정보 위치 정보 활용 사업 전개 계획 브로 영상 현재 사용자 위치 정보 때문 맛집 호텔 스팟 실시간 공유 레이 콘텐츠 희망 여행지 폴로 해당 지역 영상 공유 광고 여행 상품 비디오 몬스터 마케팅 사회 관계 서비스 최적화 내외 숏폼 영상 제작 플랫폼 비디오 몬스터 먼저 시작 전문 지식 영상 제작 래그 앤드 드롭 방식 적용 영상 가장 디자인 템플릿 자동 추천 때문 디자인 능력 사진 플랫폼 검색 삽입 폰트 영상 분위기 선택 영상 비율 유튜브 용인 비율 모바일 용인 비율 선택 대표 이용자 콘텐츠 시대 소비자 영상 기업 홍보 영상 반응 단순 편집 제공 디자인 테마 템플릿 제공 방식 영상 제작 변화 비디오 몬스터 영상 제작 비용 획기 절감 비디오 몬스터 영상 제작 템플릿 저작권 해결 이미지 음원 지원 클라우드 기반 자동 렌더링 엔진 초보자 퍼포먼스 영상 제작 현재 제품 사진 등록 템플릿 매칭 인공 지능 자동 추천 솔루션 개발 중이 비디오 몬스터 숏폼 영상 솔루션 비디오 몬스터 고객 상공 소규모 업주 지속 확대 롱폼 영상 제작 솔루션 비브 사용자 일반인 유입 사업 시너지 효과 사용자 확대 기반 비디오 몬스터 글로벌 진출 가속 계획 비디오 몬스터 지난해 해외 진출 개월 월간 이용 자수 달성 대표 영상 제작 업무 영상 전문가 비디오 몬스터 법인 설립 서비스 상반기 규모 시리즈 투자 유치 완료 이노 폴리스 파트너 스마트 스터디 벤처스 홀딩스 유니온 파트너 참여 비브 출시 하반기 시리즈 계획 스마트폰 자동차 연결 기술 세상 차량 스마트 스마트폰 갤럭시 울트라 차량 디지털 서비스 제공 스마트폰 생활 예고 디지털 초광대역 주파수 이용 정밀 위치 측정 기술 적용 기술 디지털 기존 스마트 마찬가지 주머니 스마트폰 작동 스마트폰 차량 차량 디지털 미리 등록 스마트폰 위치 인식 사용자 차량 해제 기술 적용 디지털 지원 제품 갤럭시 갤럭시 울트라 갤럭시 폴드 갤럭시 갤럭시 울트라 갤럭시 폴드 갤럭시 노트 울트라 종이 디지털 서비스 지원 패스 지문 생체 정보 사용 로그인 보안 기반 인증 플랫폼 패스 공공기관 서비스 이용 전자서명 인증서 비밀번호 형태 개인정보 통합 관리 웹사이트 로그인 모바일 뱅킹 사용 비밀번호 입력 액세스 사용자 추가 디지털 개인정보 관리 출시 지갑 플랫폼 삼성 월렛 디지털 기능 지원 예정 사용자 월렛 업데이트 디지털 사용 패스 디지털 사용 발급 먼저 현대차 제네시스 커넥티드 서비스 설치 사용자 자동차 정보 등록 차량 스마트 휴대 자동차 탑승 인포테인먼트 시스템 차량 디스플레이 디지털 메뉴 확인 자동차 조사 디지털 등록 실행 패스 자동 이후 차내 디스플레이 안내 디지털 설치 발급 완료 패스 등록 완료 기존 차량 스마트 고이 스마트폰 디지털 하나로 스마트 기능 사용 실물 필요 때문 기능 활용 차량 해제 방법 차량 설정 가지 스마트폰 가방 주머니 차량 도어 핸들 직접 해제 거나 스마트폰 휴대 가까이 자동 인식 해제 가지 방법 스마트폰 별도 작동 가득 스마트폰 가방 경우 디지털 기능 차량 탑승 외부 사용 차량 서로 인식 거리 차량 해제 설정 경적 리기 엔진 버튼 미리 시동 수도 적용 디지털 직관 보기 적용 스마트 사용자 디지털 누군가 디지털 공유 기능 이동해 공유 최대 공유 대상 연락처 추가 선택 누르기 설치 문자메시지 전송 차주 사용 기간 액세스 권한 범위 설정 공유 사람 정보 액세스 권한 한눈 수도 디지털 공유 운전자 패스 추가 사용 스마트폰 휴대 차량 디지털 인식 자동 해제 때문 삼성 패스 기반 디지털 수준 보안 칩셋 보안 사용자 디지털 정보 안전성 공유 앞서 인증 절차 거치 공 ...

# %%
print(type(preprocessed_texts))
# Out:
# <class 'list'>

# %%
with open('./data/preprocessed_it_science.txt', 'w', encoding='utf-8') as f:
    f.write(preprocessed_texts[0])
